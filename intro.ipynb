# %% [markdown]
# <a href="https://colab.research.google.com/github/chebil/stat/blob/main/intro.ipynb" target="_blank" rel="noopener noreferrer"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Applied statistics and Probability for Computer Scientists
#
#
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/0kJrFgxxq-I" title="Statistics and Probability for Computer Scientists" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
#
# ## About The course
#
# This course provides a comprehensive introduction to applied statistics and probability theory, tailored specifically for computer scientists. It covers fundamental concepts and techniques that are essential for data analysis, machine learning, and algorithm design.
#
# ## Prerequisites
#
# Basic knowledge of:
# - Python programming
# - Linear algebra
# - Calculus (introductory level)
#
# ## References
#
# **Forsyth, D. (2018). *Probability and Statistics for Computer Science*. Springer International Publishing.**
